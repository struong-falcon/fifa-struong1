# %%
from bqplot import pyplot as plt
import ipywidgets as widgets
import numpy as np

# %% [markdown]
# # Reference: https://github.com/batuhan-demirci/fifa21_dataset/tree/master/data

# %%
# generate some fake 
n = 2000
x = np.linspace(0.0, 10.0, n)
np.random.seed(0)
y = np.cumsum(np.random.randn(n)*10).astype(int)

# %%
fig_hist = plt.figure( title='Histogram')
hist = plt.hist(y, bins=25)

# %%
hist.bins = 10;

# %%
slider = widgets.IntSlider(description='Bins number', min=1, max=100, v_model=30)
# Out:
# IntSlider(value=1, description='Bins number', min=1)

# %%
widgets.link((hist, 'bins'), (slider, 'value'))

fig_lines = plt.figure( title='Line Chart')
lines = plt.plot(x, y)

fig_lines.layout.width = 'auto'
fig_lines.layout.height = 'auto'
fig_hist.layout.width = 'auto'
fig_hist.layout.height = 'auto'

grid_layout = widgets.GridspecLayout(5, 3)

grid_layout[:2, :] = fig_lines
grid_layout[2:4, :] = fig_hist
grid_layout[4, 1] = slider

grid_layout.layout.height = '1000px'

grid_layout
# Out:
# GridspecLayout(children=(Figure(axes=[Axis(scale=LinearScale()), Axis(orientation='vertical', scale=LinearScal…

# %%
selector = plt.brush_int_selector()
def update_range(*ignore):
    if selector.selected is not None and len(selector.selected) == 2:
        xmin, xmax = selector.selected
        mask = (x > xmin) & (x < xmax)
        hist.sample = y[mask]
selector.observe(update_range, 'selected')

# %%
import pandas as pd
df=pd.read_csv('tbl_player.csv')

# %%
df
# Out:
#        int_player_id                      str_player_name str_positions  \
# 0                  1       Lionel Andrés Messi Cuccittini    RW, ST, CF
# 1                  2  Cristiano Ronaldo dos Santos Aveiro        ST, LW
# 2                  3                            Jan Oblak            GK
# 3                  4                      Kevin De Bruyne       CAM, CM
# 4                  5        Neymar da Silva Santos Júnior       LW, CAM
# ...              ...                                  ...           ...
# 18997          18998                                  张梦炫            CB
# 18998          18999                        Vani Da Silva            ST
# 18999          19000                                   夏奥            CB
# 19000          19001                            Ben Hough            CM
# 19001          19002          Mateo Nicolás Flores Cuevas           CDM
#
#       dt_date_of_birth  int_height  int_weight  int_overall_rating  \
# ...

# %%
#df.isnull().values.any()
# Out:
# True

# %%
#df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19002 entries, 0 to 19001
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   int_player_id            19002 non-null  int64
#  1   str_player_name          19002 non-null  object
#  2   str_positions            19002 non-null  object
#  3   dt_date_of_birth         19002 non-null  object
#  4   int_height               19002 non-null  int64
#  5   int_weight               19002 non-null  int64
#  6   int_overall_rating       19002 non-null  int64
#  7   int_potential_rating     19002 non-null  int64
#  8   str_best_position        19002 non-null  object
#  9   int_best_overall_rating  19002 non-null  int64
#  10  int_value                19002 non-null  int64
#  11  int_wage                 19002 non-null  int64
#  12  str_player_image_url     19002 non-null  object
#  13  int_team_id              18767 non-null  float64
# ...

# %%
#df.isnull().sum().sum()
# Out:
# 235

# %%
#df['int_team_id']
# Out:
# 0          5.0
# 1          6.0
# 2          8.0
# 3          2.0
# 4          7.0
#          ...
# 18997    595.0
# 18998    646.0
# 18999    409.0
# 19000    646.0
# 19001    400.0
# Name: int_team_id, Length: 19002, dtype: float64

# %%
country_list = list(df["str_nationality"].unique())
country_list.sort()
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua & Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bolivia',
#  'Bosnia Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China PR',
#  'Chinese Taipei',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'DR Congo',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Faroe Islands',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guam',
#  'Guatemala',
#  'Guinea',
# ...

# %%
country_combobox=widgets.Combobox(
    # value='John',
    placeholder='Choose Country',
    options=country_list,
    description='Combobox:',
    ensure_option=True,
    disabled=False
)

# %%
table=df[df['str_nationality'] == country_combobox.value]
# Out:
#        int_player_id                    str_player_name str_positions  \
# 0                  1     Lionel Andrés Messi Cuccittini    RW, ST, CF
# 17                18  Sergio Leonel Agüero del Castillo            ST
# 20                21        Paulo Bruno Exequiel Dybala       CF, CAM
# 43                44    Ángel Fabián Di María Hernández        RW, LW
# 62                63              Alejandro Darío Gómez   CAM, CF, ST
# ...              ...                                ...           ...
# 18351          18352          Leandro Farid Finochietto            GK
# 18443          18444       Nicolás Alejandro Forastiero            GK
# 18455          18456            Tomás Ezequiel Canteros            GK
# 18556          18557                    Tomás Marchiori            GK
# 18596          18597                 Williams Barlasina            GK
#
#       dt_date_of_birth  int_height  int_weight  int_overall_rating  \
# ...

# %%
grid_layout = widgets.GridspecLayout(5, 3)
grid_layout[:3, :] = table

grid_layout[3:, 1] = country_combobox

grid_layout.layout.height = '1000px'

grid_layout
